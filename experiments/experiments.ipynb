# %%
from pymongo import MongoClient

username = "owais1"
password = "owais123"
uri = f"mongodb+srv://{username}:{password}@cluster0.hei4umn.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(uri)

# %%
db=client['youtubecommunity']

# %%
collection=db["session"]

# %%
data={
    "coursename":"genai",
    "instructor":"sunny",
    "modeofsession":"english"
}

# %%
try:
    result = collection.insert_one(data)
    print(f"Document inserted with ID: {result.inserted_id}")
except Exception as e:
    print("Error inserting document:", e)
# Out:
# Document inserted with ID: 690b81971a6ce1be216de5dc

# %%
all_records=collection.find()

# %%
for record in all_records:
    print(record)
# Out:
# {'_id': ObjectId('690b81971a6ce1be216de5dc'), 'coursename': 'genai', 'instructor': 'sunny', 'modeofsession': 'english'}

# %%
collection.insert_many(
    [
    {
        "coursename":"genai",
        "instructor":"sunny",
        "modeofsession":"english"
    },
    {
        "coursename":"mlops",
        "instructor":"owais",
        "modeofsession":"english&Hindi"
    }
])
# Out:
# InsertManyResult([ObjectId('690b83831a6ce1be216de5dd'), ObjectId('690b83831a6ce1be216de5de')], acknowledged=True)

# %%
import json
import pandas as pd


class mongodb_operation:
    def __init__(self,client_url:str,database_name:str, collection_name: str=None):
        self.client_url=client_url,
        self.database_name=database_name
        self.collection_name=collection_name
        
    def create_client(self):
        client=MongoClient(self.client_url)
        return client

        
    def create_database(self):
        client=self.create_client()
        database=client[self.database_name]
        return database
    
    def create_collection(self,collection:None):
        database=self.create_database()
        collection=database[self.collection_name]
        return collection

    def insert_record(self,record:dict, collection_name:str):
        if type(record)==list:
            for data in record:
                if type(data)!=dict:
                    raise TypeError("record must be in the dict")
            collection=self.create_collection(collection_name)
            collection.insert_many(record)
            
        elif type(record) == dict:
            collection=self.create_collection(collection_name)
            collection.insert_one(record)
                
    def bulk_insert(self,datafile:str,collection_name:str=None):
        self.path=datafile
        
        if self.path.endswith('.csv'):
            data=pd.read_csv(self.path,encoding='utf-8')
        
        elif self.path.endswith('.xlsx'):
           data = pd.read_excel(self.path,encoding ='utf-8')
        
        datajson=json.loads(data.to_json(orient='record'))
        collection=self.create_collection()
        collection.insert_many(datajson)

# %%
# call the mongodb connection
client_url = f"mongodb+srv://owais1:owais123@cluster0.hei4umn.mongodb.net/?retryWrites=true&w=majority"
database ="mynewdatabase"
collection_name="mynewcollection"

# %%
mongo=mongodb_operation(client_url,database,collection_name)

# %%
mongo.insert_record({'name':'owais','designation':'data scientist','salary':'10k'},collection_name)
